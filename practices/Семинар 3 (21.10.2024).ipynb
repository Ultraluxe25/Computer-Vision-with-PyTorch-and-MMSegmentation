# %% [markdown]
# <span style="color: blue">22.10.2024

# %% [markdown]
# **Цель:** Решить задачу сегментации изображений с использованием фреймворка mmseg
#
# **Задачи кратко:** подготовить рабочее окружение для работы с фреймворком mmseg, обучить нейронную сеть для решения задачи сегментации изображений
#
# Рекомендуемые требования к окружению:
#
# 1.	Ubuntu 22.04
# 2.	Python 3.10+
# 3.	Pytorch 2+
# 4.	Virtual env
# 5.	Visual Studio Code
# 6.	Git (gitlab)
# 7.	mmseg >= 1.1.0
#
# **Задачи:**
#
# 1.	Ознакомиться с фреймворком https://github.com/open-mmlab/mmsegmentation/blob/main/docs/en/overview.md
# 2.	Установить фреймворк mmseg https://github.com/open-mmlab/mmsegmentation/blob/main/docs/en/get_started.md#installation
# 3.	Изучить структуру конфигурационного файла https://github.com/open-mmlab/mmsegmentation/blob/main/docs/en/user_guides/1_config.md
# 4.	Подготовить датасет COCO Stuff 10k https://github.com/open-mmlab/mmsegmentation/blob/main/docs/en/user_guides/2_dataset_prepare.md#coco-stuff-10k
# 5.	Обучить модель https://github.com/open-mmlab/mmsegmentation/blob/main/docs/en/user_guides/4_train_test.md

# %% [markdown]
# ![image.png](attachment:12adf4b5-7169-4b00-a38b-c0be034550ad.png)

# %% [markdown]
# ### В MMSeg в одтельных модулях реализованны основные модели DL. Построен на базе PyTorch.
# ![image.png](attachment:824699e9-57dd-48fa-8559-f510dde61497.png)

# %% [markdown]
# ### Это первое что надо будет почитать по этому фреймворку [Get started: Install and Run MMSeg](https://mmsegmentation.readthedocs.io/en/latest/get_started.html)
# ![image.png](attachment:9e7591b9-5ba9-406c-b4c0-ff5debfa475d.png)

# %% [markdown]
# ### Через докер устанавливать не стоит, т.к. у нас не будет root-доступа к серверу на котором мы будем обучать модели

# %% [markdown]
# ### Вместо pip используется mmcv для установки зависимостей

# %% [markdown]
# [Здесь лежат модели для сегментации с помощью MMSeg](https://github.com/open-mmlab/mmsegmentation/blob/main/docs/en/model_zoo.md)

# %% [markdown]
# ### Для обучения на CPU лучше использовать вот эту модель
# ![image.png](attachment:392cce07-3d10-4f8e-8187-f2bb0f29afe8.png)

# %% [markdown]
# ### В первых 4х семинарах нам не нужен классный результат на метриках, главное чтобы с каждой эпохой уменьшалось значение функции потерь и росла точность

# %% [markdown]
# ![image.png](attachment:f6eb04a5-092d-434f-9d93-4f90bd456e5f.png)

# %% [markdown]
# ### Сверточные слои и пуллинг умещается в backbone, а полносвязные слои в decode_head

# %% [markdown]
# ### Часто процесс подготовки данных (аугментация и их загрузка) происходит медленнее чем обучение модели на GPU

# %% [markdown]
# ![image.png](attachment:36ccdda3-4dcd-4110-a3e3-99fa50ace13b.png)
