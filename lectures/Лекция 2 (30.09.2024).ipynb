# %% [markdown]
# ![image.png](attachment:c761d5c4-8058-49f4-8aca-58f1d92a7b4b.png)

# %% [markdown]
# ![image.png](attachment:7e6e6947-7e9f-419a-a98f-733464aab2f6.png)

# %% [markdown]
# ### При выборе функции активации нужно учесть проблему затухающего градиента

# %% [markdown]
# ![image.png](attachment:475dc9f9-ff33-452c-9316-183503118f98.png)

# %% [markdown]
# ### Важно уметь разбираться в оптимизаторах градиентного спуска. Стохастический GD потому что вектор градиента считается на одном случайном наблюдении выборки

# %% [markdown]
# ### Использовать batch normalization чтобы веса не выходили за границы допустимых

# %% [markdown]
# ### Стохастический градиентный спуск всегда к чему-то сойдется. Если модель не сойдется, значит нужно уменьшить шаг. Если и это не поможет, то значит ошибка в данных. Зигзагообразное движение, т.к. значения случайные (туда-сюда)

# %% [markdown]
# ![image.png](attachment:bfeb18f3-5a8c-4bad-a19f-b14be57cf523.png)

# %% [markdown]
# ![image.png](attachment:1cf06167-d42d-4879-bd5c-8a02661e9825.png)

# %% [markdown]
# # День 2 часть 1 40:00 минут

# %% [markdown]
# ![image.png](attachment:9b994142-33e4-4135-b0c6-bd31cfecfa74.png)
# ## По мини-батчу градиентный спуск не потребляет много ресурсов (временных) и работает эффективнее. В SGD зигзагообразная траектория потому что размер батча равен 1 (один случайный объект)

# %% [markdown]
# ### Cчета Meta за электричество (на обучение нейронок) уже исчисляется в десятках миллионах долларах

# %% [markdown]
# ### Размер батча обычно 32 или 64 объекта и доходит до 256. В батч нужно стараться включить много разнообразных примеров чтобы градиент на каждой итерации если и менял направление, то незначительно

# %% [markdown]
# ![image.png](attachment:dfd19979-0bf3-45d5-89bb-167f49fa8698.png)

# %% [markdown]
# ![image.png](attachment:ebf2c271-865b-40cf-982f-94b7a323d2c2.png)

# %% [markdown]
# ### 0. Стохастический градиентный спуск с моментом инерции. Если не знаешь из данных задачи какой оптимизатор использовать, тогда используй Adam или SAG (SGD)

# %% [markdown]
# # Ни один из оптимизаторов не гарантирует нам что мы получим глобальное решение. Поэтому мы ищем самый лучший глобальный минимум за приемлимую цену ресурсов

# %% [markdown]
# ![image.png](attachment:a7c87dfa-a79c-4e99-872b-549b68bf379d.png)
# ### Накопленный импульс помогает нам выскочить из локального минимума в поисках глобального, а не застрять

# %% [markdown]
# ### Гиперпараметры не оптимизируются в процессе обучения, они подбираются самим разработчиком (шаг градиентного спуска). Шаг должен быть не более 0.05
