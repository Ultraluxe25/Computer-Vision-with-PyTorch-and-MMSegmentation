# %% [markdown]
# ![image.png](attachment:642b49ba-fd98-479f-a436-2422be9c3940.png)
# ### Один из подходов unpooling

# %% [markdown]
# ![image.png](attachment:e3afc99c-3c2b-4758-83e3-829d83f08209.png)

# %% [markdown]
# ![image.png](attachment:a455df98-261b-4c51-aa1d-d95a2cea20fe.png)

# %% [markdown]
# ### Лучше решать задачу одной нейронной сетью чем несколькими...

# %% [markdown]
# ![image.png](attachment:634b2511-0f5e-403c-a1a4-edd6a0ae606f.png)
# ### Левая часть U-Net называется backbone

# %% [markdown]
# ![image.png](attachment:be264f3f-f608-44f2-af1e-ff3548821b2a.png)
# ### Рисуя архитектуры сейчас часто изображают блок, в котором зашиты много слоев

# %% [markdown]
# ![image.png](attachment:84d35115-919c-42e2-aa37-6feecffad0dd.png)
